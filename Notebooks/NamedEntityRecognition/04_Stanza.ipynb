# %%
import stanza
from spacy.scorer import Scorer
from spacy.gold import GoldParse

# %%
stanza.download('fr') 
nlp = stanza.Pipeline('fr')
# Out:
# ...
# 2020-11-26 19:53:38 INFO: Downloading default packages for language: fr (French)...
# 2020-11-26 19:53:39 INFO: File exists: /Users/amalbedoui/stanza_resources/fr/default.zip.
# 2020-11-26 19:53:44 INFO: Finished downloading models and saved to /Users/amalbedoui/stanza_resources.
# 2020-11-26 19:53:44 INFO: Loading these models for language: fr (French):
# ...
# | Processor | Package |
# -----------------------
# | tokenize  | gsd     |
# | mwt       | gsd     |
# | pos       | gsd     |
# | lemma     | gsd     |
# | depparse  | gsd     |
# | ner       | wikiner |
# ...
#
# 2020-11-26 19:53:44 INFO: Use device: cpu
# 2020-11-26 19:53:44 INFO: Loading: tokenize
# 2020-11-26 19:53:44 INFO: Loading: mwt
# 2020-11-26 19:53:44 INFO: Loading: pos
# 2020-11-26 19:53:44 INFO: Loading: lemma
# 2020-11-26 19:53:45 INFO: Loading: depparse
# 2020-11-26 19:53:46 INFO: Loading: ner
# 2020-11-26 19:53:47 INFO: Done loading processors!

# %%
doc = nlp("Emma Louise, 26 rue Alexandre, 75005, Paris, France, née le 11/11/2007 et joignable sur 06660006, Palaiseau.") 
print(doc)
# Out:
# [
#   [
#     {
#       "id": 1,
#       "text": "Emma",
#       "lemma": "Emma",
#       "upos": "PROPN",
#       "head": 0,
#       "deprel": "root",
#       "misc": "start_char=0|end_char=4",
#       "ner": "B-PER"
#     },
#     {
#       "id": 2,
#       "text": "Louise",
#       "lemma": "Louise",
#       "upos": "PROPN",
#       "head": 1,
#       "deprel": "flat:name",
#       "misc": "start_char=5|end_char=11",
#       "ner": "E-PER"
#     },
#     {
#       "id": 3,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "head": 4,
#       "deprel": "punct",
#       "misc": "start_char=11|end_char=12",
#       "ner": "O"
#     },
#     {
#       "id": 4,
#       "text": "26",
#       "lemma": "26",
#       "upos": "NUM",
#       "head": 1,
#       "deprel": "nmod",
#       "misc": "start_char=13|end_char=15",
#       "ner": "O"
#     },
#     {
#       "id": 5,
#       "text": "rue",
#       "lemma": "rue",
#       "upos": "NOUN",
# ...

# %%
print(doc.entities)
# Out:
# [{
#   "text": "Emma Louise",
#   "type": "PER",
#   "start_char": 0,
#   "end_char": 11
# }, {
#   "text": "rue Alexandre",
#   "type": "LOC",
#   "start_char": 16,
#   "end_char": 29
# }, {
#   "text": "Paris",
#   "type": "LOC",
#   "start_char": 38,
#   "end_char": 43
# }, {
#   "text": "France",
#   "type": "LOC",
#   "start_char": 45,
#   "end_char": 51
# }, {
#   "text": "Palaiseau",
#   "type": "LOC",
#   "start_char": 98,
#   "end_char": 107
# }]
