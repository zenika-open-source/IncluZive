# %% [markdown]
# # Importation des librairies

# %%
import spacy
from spacy import displacy
import fr_core_news_sm
from prettytable import PrettyTable
from spacy.scorer import Scorer
from spacy.gold import GoldParse
from spacy.scorer import Scorer

# %% [markdown]
# # 1) Exemple en anglais

# %%
nlp = spacy.load("en_core_web_sm")

# %%
doc = nlp("I think Barack Obama met founder of Facebook at occasion of a release of a new NLP this month algorithm his phone number was :5555551234.")

# %% [markdown]
# ## a) POS Tagging

# %%
displacy.render(doc, style="dep") # (1)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="6b095e36a72442348fddd711557c42d6-0" class="displacy" width="4425" height="574.5" direction="ltr" style="max-width: none; height: 574.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">think</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">Barack</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">Obama</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">met</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">founder</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">Facebook</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">at</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">occasion</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">release</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">new</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">NLP</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">this</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">month</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">algorithm</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3550">his</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3725">phone</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3900">number</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4075">was :</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4250">5555551234.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">NUM</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6b095e36a72442348fddd711557c42d6-0-0" stroke-width="2px" d="M70,439.5 C70,352.0 205.0,352.0 205.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6b095e36a72442348fddd711557c42d6-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,441.5 L62,429.5 78,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6b095e36a72442348fddd711557c42d6-0-1" stroke-width="2px" d="M420,439.5 C420,352.0 555.0,352.0 555.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6b095e36a72442348fddd711557c42d6-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,441.5 L412,429.5 428,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6b095e36a72442348fddd711557c42d6-0-2" stroke-width="2px" d="M595,439.5 C595,352.0 730.0,352.0 730.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href

# %% [markdown]
# ## b) Named Entities

# %%
displacy.render(doc, style="ent") # (2)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">I think
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Barack Obama
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  met founder of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Facebook
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  at occasion of a release of a new
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NLP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     this month
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  algorithm his phone number was :
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5555551234
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .</div></span>

# %% [markdown]
# # 2) Exemple en français

# %%
nlp = fr_core_news_sm.load()
doc = nlp("Emma Louise s'est installée au 26 rue Alexandre 75005 Paris France, elle est née en 2007 et elle est joignable sur 06660006.")

# %% [markdown]
# ## a) Pos tagging

# %%
x = PrettyTable()
y=PrettyTable()

# %%
x.field_names =  ["text", "lemma_", "pos_","tag_","dep_","shape_", "alpha", ".is_stop"]

# %%
for token in doc:
    x.add_row([token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
            token.shape_, token.is_alpha, token.is_stop])

# %%
options = {"distance": 130}
displacy.render(doc, style="dep", options=options) # (1)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="fr" id="784771b7d9364fd68204f046cac061c8-0" class="displacy" width="3040" height="592.0" direction="ltr" style="max-width: none; height: 592.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="502.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Emma</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="502.0">
#     <tspan class="displacy-word" fill="currentColor" x="180">Louise</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="180">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="502.0">
#     <tspan class="displacy-word" fill="currentColor" x="310">s'</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="310">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="502.0">
#     <tspan class="displacy-word" fill="currentColor" x="440">est</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="440">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="502.0">
#     <tspan class="displacy-word" fill="currentColor" x="570">installée</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="570">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="502.0">
#     <tspan class="displacy-word" fill="currentColor" x="700">au</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="700">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="502.0">
#     <tspan class="displacy-word" fill="currentColor" x="830">26</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="830">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="502.0">
#     <tspan class="displacy-word" fill="currentColor" x="960">rue</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="960">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="502.0">
#     <tspan class="displacy-word" fill="currentColor" x="1090">Alexandre</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1090">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="502.0">
#     <tspan class="displacy-word" fill="currentColor" x="1220">75005</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1220">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="502.0">
#     <tspan class="displacy-word" fill="currentColor" x="1350">Paris</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1350">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="502.0">
#     <tspan class="displacy-word" fill="currentColor" x="1480">France,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1480">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="502.0">
#     <tspan class="displacy-word" fill="currentColor" x="1610">elle</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1610">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="502.0">
#     <tspan class="displacy-word" fill="currentColor" x="1740">est</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1740">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="502.0">
#     <tspan class="displacy-word" fill="currentColor" x="1870">née</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1870">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="502.0">
#     <tspan class="displacy-word" fill="currentColor" x="2000">en</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2000">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="502.0">
#     <tspan class="displacy-word" fill="currentColor" x="2130">2007</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2130">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="502.0">
#     <tspan class="displacy-word" fill="currentColor" x="2260">et</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2260">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="502.0">
#     <tspan class="displacy-word" fill="currentColor" x="2390">elle</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2390">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="502.0">
#     <tspan class="displacy-word" fill="currentColor" x="2520">est</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2520">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="502.0">
#     <tspan class="displacy-word" fill="currentColor" x="2650">joignable</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2650">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="502.0">
#     <tspan class="displacy-word" fill="currentColor" x="2780">sur</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2780">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="502.0">
#     <tspan class="displacy-word" fill="currentColor" x="2910">06660006.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2910">NUM</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-784771b7d9364fd68204f046cac061c8-0-0" stroke-width="2px" d="M70,457.0 C70,197.0 555.0,197.0 555.0,457.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-784771b7d9364fd68204f046cac061c8-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj:pass</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,459.0 L62,447.0 78,447.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-784771b7d9364fd68204f046cac061c8-0-1" stroke-width="2px" d="M70,457.0 C70,392.0 150.0,392.0 150.0,457.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-784771b7d9364fd68204f046cac061c8-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">flat:name</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M150.0,459.0 L158.0,447.0 142.0,447.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-784771b7d9364fd68204f046cac061c8-0-2" stroke-width="2px" d="M330,457.0 C330,327.0 545.0,327.0 545.0,457.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-784771b7d9364fd68204f046cac061c8-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">expl:comp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M330,459.0 L322,447.0 338,447.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-784771b7d9364fd68204f046cac061c8-0-3" stroke-width="2px" d="M460,457.0 C460,392.0 540.0,392.0 540.0,457.0" fill="none" stroke="currentColor"/>
#     <t

# %%
print (x)
# Out:
# +-----------+-----------+-------+------------------------------------------------------------+------------+--------+-------+----------+
# |    text   |   lemma_  |  pos_ |                            tag_                            |    dep_    | shape_ | alpha | .is_stop |
# +-----------+-----------+-------+------------------------------------------------------------+------------+--------+-------+----------+
# |    Emma   |    Emma   | PROPN |               PROPN__Gender=Masc|Number=Sing               | nsubj:pass |  Xxxx  |  True |  False   |
# |   Louise  |   Louise  | PROPN |                           PROPN                            | flat:name  | Xxxxx  |  True |  False   |
# |     s'    |     se    |  PRON |                 PRON__Person=3|Reflex=Yes                  | expl:comp  |   x'   | False |   True   |
# |    est    |    être   |  AUX  | AUX__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin | aux:tense  |  xxx   |  True |   True   |
# | installée | installer |  VERB |   VERB__Gender=Fem|Number=Sing|Tense=Past|VerbForm=Part    |    ROOT    |  xxxx  |  True |  False   |
# |     au    |     au    |  DET  | ADP_DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art |    case    |   xx   |  True |   True   |
# |     26    |     26    |  NUM  |                     NUM__NumType=Card                      |  obl:mod   |   dd   | False |  False   |
# |    rue    |    rue    |  NOUN |                NOUN__Gender=Fem|Number=Sing                |    nmod    |  xxx   |  True |  False   |
# | Alexandre | Alexandre | PROPN |                           PROPN                            |    nmod    | Xxxxx  |  True |  False   |
# |   75005   |   75005   |  NUM  |                     NUM__NumType=Card                      |    nmod    |  dddd  | False |  False   |
# |   Paris   |   Paris   | PROPN |               PROPN__Gender=Masc|Number=Sing               |    dep     | Xxxxx  |  True |  False   |
# |   France  |   France  | PROPN |               PROPN__Gender=Fem|Number=Sing                | flat:name  | Xxxxx  |  True |  False   |
# |     ,     |     ,     | PUNCT |                           PUNCT                            |   punct    |   ,    | False |  False   |
# |    elle   |    lui    |  PRON |           PRON__Gender=Fem|Number=Sing|Person=3            |   nsubj    |  xxxx  |  True |   True   |
# |    est    |    être   |  AUX  | AUX__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin | aux:tense  |  xxx   |  True |   True   |
# |    née    |   naître  |  VERB |   VERB__Gender=Fem|Number=Sing|Tense=Past|VerbForm=Part    | parataxis  |  xxx   |  True |  False   |
# |     en    |     en    |  ADP  |                            ADP                             |    case    |   xx   |  True |   True   |
# |    2007   |    2007   |  NUM  |                     NUM__NumType=Card                      |  obl:mod   |  dddd  | False |  False   |
# |     et    |     et    | CCONJ |                           CCONJ                            |     cc     |   xx   |  True |   True   |
# |    elle   |    lui    |  PRON |           PRON__Gender=Fem|Number=Sing|Person=3            | nsubj:pass |  xxxx  |  True |   True   |
# |    est    |    être   |  AUX  | AUX__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin |  aux:pass  |  xxx   |  True |   True   |
# | joignable | joignable |  ADJ  |                      ADJ__Number=Sing                      |    conj    |  xxxx  |  True |  False   |
# |    sur    |    sur    |  ADP  |                            ADP                             |    case    |  xxx   |  True |   True   |
# |  06660006 |  06660006 |  NUM  |                     NUM__NumType=Card                      |  obl:mod   |  dddd  | False |  False   |
# |     .     |     .     | PUNCT |                           PUNCT                            |   punct    |   .    | False |  False   |
# +-----------+-----------+-------+------------------------------------------------------------+------------+--------+-------+----------+

# %% [markdown]
# ## b) Named Entities

# %%
y.field_names = ["text", "start_char", "end_char", "label_"]

# %%
for ent in doc.ents:
    y.add_row([ent.text, ent.start_char, ent.end_char, ent.label_])

# %%
displacy.render(doc, style="ent") # (2)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Emma Louise
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  s'est installée au 26
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     rue Alexandre
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  75005
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Paris France
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , elle est née en 2007 et elle est joignable sur 06660006.</div></span>

# %%
print(y)
# Out:
# +---------------+------------+----------+--------+
# |      text     | start_char | end_char | label_ |
# +---------------+------------+----------+--------+
# |  Emma Louise  |     0      |    11    |  PER   |
# | rue Alexandre |     34     |    47    |  LOC   |
# |  Paris France |     54     |    66    |  LOC   |
# +---------------+------------+----------+--------+

# %% [markdown]
# ## c) Métriques d'évaluation

# %%
def evaluate(ner_model, examples):
    scorer = Scorer()
    for input_, annot in examples:
        doc_gold_text = ner_model.make_doc(input_)
        gold = GoldParse(doc_gold_text, entities=annot)
        pred_value = ner_model(input_)
        scorer.score(pred_value, gold)
    return scorer.scores# example run

# %%
examples = [
    ("Je suis Marie Antoinette. J'habite à London. Diplômée en 2018 et joignable sur 06660006",[(8,24,"PER"),(37,43,"LOC")]),
    ("François travaille chez la société française Zenika depuis 2011. Il était recruté initialement à Montréal.",[(0,8,"PER"),(35,44,"MISC"),(45,51,"ORG"),(107,115,"LOC")]),
    ("Frédéric, 34 ans, installé à Lyon.",[(0,8,"PER"),(29,33,"LOC")]),
    ("Amélie habite à Palaiseau depuis son arrivée en France ",[(0,6,"PER"),(16,25,"LOC"),(48,54,"LOC")]),
    ("Julien travaille à Asnières-sur-Seine chez FBI.",[(0,6,"PER"),(19,37,"LOC"),(43,46,"ORG")]),
    ("Jack est consultant chez Google.",[(0,4,"PER"),(25,31,"ORG")]),
    ("Les anglais sont chaleureux.",[(4,11,"MISC")]),
]

# %%
results = evaluate(nlp, examples)

# %%
print("Précision des entités: ",results.get("ents_p"))
print("Rappel des entités: ",results.get("ents_r"))
print("F-score des entités: ",results.get("ents_f"))
print("Métriques de l'entité PER: ",results.get("ents_per_type").get("PER"))
print("Métriques de l'entité LOC: ",results.get("ents_per_type").get("LOC"))
print("Métriques de l'entité ORG: ",results.get("ents_per_type").get("ORG"))
print("Métriques de l'entité MISC: ",results.get("ents_per_type").get("MISC"))
# Out:
# Précision des entités:  86.66666666666667
# Rappel des entités:  81.25
# F-score des entités:  83.87096774193549
# Métriques de l'entité PER:  {'p': 85.71428571428571, 'r': 100.0, 'f': 92.3076923076923}
# Métriques de l'entité LOC:  {'p': 83.33333333333334, 'r': 100.0, 'f': 90.9090909090909}
# Métriques de l'entité ORG:  {'p': 100.0, 'r': 66.66666666666666, 'f': 80.0}
# Métriques de l'entité MISC:  {'p': 0.0, 'r': 0.0, 'f': 0.0}
